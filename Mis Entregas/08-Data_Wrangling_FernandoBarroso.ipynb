# %% [markdown]
# ![imagen](https://i.pinimg.com/564x/f3/78/a4/f378a41b3f1232b42bb4b30a64552ca4.jpg)
#
# # Data Wrangling
# El data wrangling cuenta con cinco pasos principales: explorar, transformar, limpiar, enriquecer y almacenar.

# %%
import requests
from datetime import date, timedelta
import plotly.express as px
import plotly.graph_objects as go
import numpy as np
import pandas as pd

# %% [markdown]
# ### Importación de datos

# %%
# Configura tu clave de API de la NASA
api_key = 'PSNQRV93quuyth4x59j2YFK7D0PXJXHQjxnizShQ'

# %%
# Obtener la fecha de inicio (1 de enero de 2023)
fecha_inicio = date(2023, 1, 1)

# Obtener la fecha de fin (31 de diciembre de 2023)
fecha_fin = date(2023, 12, 31)

# Crear un DataFrame vacío para almacenar los eventos astronómicos
eventos = []

# Consultar la API APOD para cada día del año 2023
fecha = fecha_inicio
while fecha <= fecha_fin:
    fecha_str = fecha.strftime('%Y-%m-%d')
    url = f'https://api.nasa.gov/planetary/apod?date={fecha_str}&api_key={api_key}'
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        eventos.append({
            'Fecha': fecha_str,
            'Título': data.get('title', ''),
            'Explicación': data.get('explanation', ''),
            'URL': data.get('url', ''),
            'Créditos': data.get('copyright', ''),
            'HdURL': data.get('hdurl', ''),
            'MediaTipo': data.get('media_type', ''),
        })
    fecha += timedelta(days=1)

# %%
eventos_df = pd.DataFrame(eventos)

# %% [markdown]
# ## Exploración inicial de datos:

# %%
eventos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Fecha        260 non-null    object
#  1   Título       260 non-null    object
#  2   Explicación  260 non-null    object
#  3   URL          260 non-null    object
#  4   Créditos     260 non-null    object
#  5   HdURL        260 non-null    object
#  6   MediaTipo    260 non-null    object
# dtypes: object(7)
# memory usage: 14.3+ KB

# %%
eventos_df.tail(3)
# Out:
#           Fecha                                             Título  \
# 257  2023-09-15              Venus, Moon, and the Smoking Mountain
# 258  2023-09-16                              Fireball over Iceland
# 259  2023-09-17  Moon Mountains Magnified during Ring of Fire E...
#
#                                            Explicación  \
# 257  Venus has returned, now appearing in planet Ea...
# 258  On September 12, from a location just south of...
# 259  What are those dark streaks in this composite ...
#
#                                                    URL  \
# 257  https://apod.nasa.gov/apod/image/2309/IMG_3603...
# 258  https://apod.nasa.gov/apod/image/2309/_DSC7280...
# 259  https://apod.nasa.gov/apod/image/2309/BeadMoun...
#
#                                Créditos  \
# 257     \nLuis Miguel Meade Rodríguez\n
# 258                   Jennifer Franklin
# 259  \nWang Letian  \n(Eyes at Night)\n
#
#                                                  HdURL MediaTipo
# 257  https://apod.nasa.gov/apod/image/2309/IMG_3603...     image
# 258  https://apod.nasa.gov/apod/image/2309/_DSC7280...     image
# 259  https://apod.nasa.gov/apod/image/2309/BeadMoun...     image

# %% [markdown]
# ## Limpieza de datos:

# %%
eventos_df.loc[eventos_df['Créditos'] == ""]
# Out:
#           Fecha                                             Título  \
# 0    2023-01-01               The Largest Rock in our Solar System
# 7    2023-01-08                      Where Your Elements Came From
# 12   2023-01-13                         Young Star Cluster NGC 346
# 14   2023-01-15                    M1: The Crab Nebula from Hubble
# 17   2023-01-18  MACS0647: Gravitational Lensing of the Early U...
# ..          ...                                                ...
# 231  2023-08-20                        A Roll Cloud Over Wisconsin
# 240  2023-08-29                Unusual Spiral Galaxy M66 from Webb
# 245  2023-09-03             Comet Schwassmann-Wachmann 3 Fragments
# 254  2023-09-12                Galaxy Cluster Abell 370 and Beyond
# 255  2023-09-13          NGC 4632: Galaxy with a Hidden Polar Ring
#
#                                            Explicación  \
# 0    There, that dot on the right, that's the large...
# 7    The hydrogen in your body, present in every mo...
# 12   The most massive young star cluster in the Sma...
# 14   This is the mess that is left when a star expl...
# 17   Gravitational lensing by the galaxy cluster MA...
# ..                                                 ...
# 231  What kind of cloud is this?  A type of arcus c...
# 240  Why isn't spiral galaxy M66 symmetric?  Usuall...
# 245  Periodic comet 73P/Schwassmann-Wachmann 3 has ...
# 254  Some 4 billion light-years away, massive galax...
# 255  Galaxy NGC 4632 hides a secret from optical te...
#
#                                                    URL Créditos  \
# 0    https://apod.nasa.gov/apod/image/2301/PaleBlue...
# 7    https://apod.nasa.gov/apod/image/2301/Nucleosy...
# 12   https://apod.nasa.gov/apod/image/2301/jwst-ngc...
# 14   https://apod.nasa.gov/apod/image/2301/CrabNebu...
# 17   https://apod.nasa.gov/apod/image/2301/MacsClus...
# ..                                                 ...      ...
# 231  https://apod.nasa.gov/apod/image/2308/rollclou...
# 240  https://apod.nasa.gov/apod/image/2308/M66_Jwst...
# 245  https://apod.nasa.gov/apod/image/2309/fragb73p...
# 254  https://apod.nasa.gov/apod/image/2309/STSCI-HS...
# 255  https://apod.nasa.gov/apod/image/2309/PolarRin...
#
#                                                  HdURL MediaTipo
# 0    https://apod.nasa.gov/apod/image/2301/PaleBlue...     image
# 7    https://apod.nasa.gov/apod/image/2301/Nucleosy...     image
# 12   https://apod.nasa.gov/apod/image/2301/jwst-ngc...     image
# 14   https://apod.nasa.gov/apod/image/2301/CrabNebu...     image
# 17   https://apod.nasa.gov/apod/image/2301/MacsClus...     image
# ..                                                 ...       ...
# 231  https://apod.nasa.gov/apod/image/2308/rollclou...     image
# 240  https://apod.nasa.gov/apod/image/2308/M66_Jwst...     image
# 245  https://apod.nasa.gov/apod/image/2309/fragb73p...     image
# 254  https://apod.nasa.gov/apod/image/2309/STSCI-HS...     image
# 255  https://apod.nasa.gov/apod/image/2309/PolarRin...     image
#
# [92 rows x 7 columns]

# %%
eventos_df['Créditos'] = eventos_df['Créditos'].replace("",None)

# %%
print("Cantidad de Nulos:", eventos_df.loc[eventos_df['Créditos'].isnull()].shape[0])
print("Cantidad de noticias con copropietarios:", eventos_df.loc[eventos_df['Créditos'].str.contains('&', na=False)].shape[0])
# Out:
# Cantidad de Nulos: 92
# Cantidad de noticias con copropietarios: 10

# %% [markdown]
# ## Transformación de datos:

# %%
# Convertir la columna de Fecha a tipo de dato datetime
eventos_df['Fecha'] = pd.to_datetime(eventos_df['Fecha'])

# Agregar una columna de Mes para agrupar por mes
eventos_df['periodo'] = eventos_df['Fecha'].dt.strftime('%Y-%m')

# Ordena el DataFrame por la columna "periodo"
eventos_df = eventos_df.sort_values(by='periodo')

# %%
def escritores(texto):
    texto = texto.replace("\n","").replace(",","&").split("(")[0].split("/")[0].split(";")[0]
    return texto

# %%
# Dividimos la coparticipacion en la columna Créditos
# eventos_df['Créditos'] = eventos_df['Créditos'].apply(escritores)
eventos_df[['Colaborador', 'Colaborador2']] = eventos_df['Créditos'].str.split(',', n=1, expand=True)

# %%
# Se elimina las columnas innecesarias para un análisis
eventos_df.drop(columns=["URL","HdURL","MediaTipo","Créditos"], inplace=True)

# %%
# El diccionario a continuación es usado para clasificar las noticias segun el titulo o descripción
palabras_clave = {
    'Cometa': ['Comet'],
    'Supernova': ['Supernova'],
    'Meteorito': ['Meteor', 'Meteorite','Meteors'],
    'Eclipse': ['Eclipse', 'Solar Eclipse', 'Lunar Eclipse'],
    'Galaxia': ['Galaxy', 'Spiral Galaxy', 'Elliptical Galaxy'],
    'Nebulosa': ['Nebula', 'Nebular', 'Nebulosity', 'Galaxy', 'Stellar Cloud'],
    'Planeta Enano': ['Dwarf Planet'],
    'Planeta': ['Planet', 'Planetary', 'Mars', 'Venus', 'Jupiter', 'Saturn', 'Neptune', 'Uranus', 'Mercury'],
    'Agujero Negro': ['Black Hole'],
    'Satélite Natural': ['Moon', 'Lunar'],
    'Asterismo': ['Asterism'],
    'Constelación': ['Constellation'],
    'Aurora': ['Aurora'],
    'Estrella': ['Star', 'Stellar'],
    'Estacion': ['Space Station', 'ISS', 'Orbit', 'Space Station', 'Low Earth Orbit','International Space Station'],
    'Cúmulo Estelar': ['Star Cluster'],
    'Evento Celestial': ['Celestial Event'],
    'Luna': ['Moon', 'Lunar'],
    'Otro': [],  # Si no se encuentra ninguna coincidencia, se clasifica como "Otro"
}

# %%
def asignar_categoria(titulo, descripcion):
    """
    Esta función toma un título y una descripción como entrada y asigna una categoría
    a un evento basándose en palabras clave predefinidas. La función busca palabras
    clave tanto en el título como en la descripción y asigna la primera categoría que
    encuentre. Si no encuentra ninguna coincidencia, se asigna la categoría "Otro".

    :param titulo: El título del evento que se evaluará para determinar la categoría.
    :param descripcion: La descripción del evento que también se evaluará para la categoría.
    :return: Una cadena que representa la categoría asignada al evento.

    referencia: https://exoplanets.nasa.gov/discovery/exoplanet-catalog/
    """
    for categoria, palabras in palabras_clave.items():
        for palabra in palabras:
            if palabra.lower() in titulo.lower():
                return categoria
            elif palabra.lower() in descripcion.lower():
                return categoria
    return 'Otro'

# %%
# Aplicar la función para asignar categorías a cada evento
eventos_df['Categoria'] = eventos_df.apply(lambda x: asignar_categoria(x['Título'],x['Explicación']),axis=1)

# %%
def asignar_subcategoria(descripcion):
    """
    Esta función toma una descripción como entrada y asigna una subcategoría
    a los eventos de eclipse en función de la presencia de ciertas palabras clave
    en la descripción. Las subcategorías posibles son "Solar", "Lunar" o "N/A" (No Aplicable).

    :param descripcion: La descripción del evento que se evaluará para determinar la subcategoría.
    :return: Una cadena que representa la subcategoría del evento ("Solar", "Lunar" o "N/A").
    """
    if 'Solar Eclipse' in descripcion:
        return 'Solar'
    elif 'Lunar Eclipse' in descripcion:
        return 'Lunar'
    else:
        return 'N/A'  # Si no se encuentra ninguna coincidencia, se asigna "N/A"

# %%
# Aplicar la función para asignar subcategorías a los eventos de eclipse
eventos_df['Subcategoria'] = eventos_df['Explicación'].apply(asignar_subcategoria)

# %%
# Lista de planetas y cuerpos celestes.
planetas = ["Mars", 'Jupiter', 'Venus', 'Neptune', 'Saturn', 'Earth', 'Mercury', 'Uranus', 'Pluto', 'NGTS-10b', 'TYC 8998-760-1', "Solar","Sun"]

# Función que busca un planeta en un texto dado y lo devuelve si lo encuentra.
def planeta(texto):
    """
    Esta función toma un texto como entrada y busca si alguna de las palabras
    en la lista 'planetas' está presente en el texto, sin importar las mayúsculas
    o minúsculas. Si encuentra una coincidencia, devuelve el nombre del planeta
    encontrado. Si no encuentra ninguna coincidencia, devuelve None.

    :param texto: El texto en el que se buscará un planeta.
    :return: El nombre del planeta encontrado o None si no se encuentra ninguno.
    """
    for p in planetas:
        if p.lower() in texto.lower():
            return p

# %%
# Aplicar la función 'planeta' a la columna 'Título' del DataFrame 'eventos_df'
# y guardar los resultados en una nueva columna llamada 'Subcategoria'.
eventos_df['Subcategoria'] = eventos_df['Título'].apply(planeta)

# %%
eventos_df.loc[(eventos_df["Subcategoria"].isnull()) & (eventos_df["Categoria"] == "Planeta")]
# Out:
#          Fecha                               Título  \
# 5   2023-01-06                    Moon O'Clock 2022
# 55  2023-02-25            Crescent Moon Occultation
# 31  2023-02-01      The Seventh World of Trappist-1
# 89  2023-03-31                         Seeing Titan
# 84  2023-03-26                            Wanderers
# 69  2023-03-11                             3D Bennu
# 95  2023-04-06              Terran 1 Burns Methalox
# 139 2023-05-20                     Galileo's Europa
# 147 2023-05-28    Ida and Dactyl: Asteroid and Moon
# 125 2023-05-06                 Twilight in a Flower
# 130 2023-05-11        Fomalhaut's Dusty Debris Disk
# 174 2023-06-24                         3D Ingenuity
# 156 2023-06-06                     Star Eats Planet
# 202 2023-07-22  Apollo 11: Armstrong's Lunar Selfie
# 186 2023-07-06               Fireworks vs Supermoon
# 188 2023-07-08                      Stickney Crater
# 193 2023-07-13                  Webb's Rho Ophiuchi
# 241 2023-08-30                 Full Moons of August
# 214 2023-08-03          The Falcon and the Redstone
# 215 2023-08-04                   Moonrays of August
#
#                                            Explicación  periodo  \
# 5    The first Full Moon of 2023 is in the sky toni...  2023-01
# 55   On February 22, a young Moon shared the wester...  2023-02
# 31   Seven worlds orbit the ultracool dwarf star TR...  2023-02
# 89   Shrouded in a thick atmosphere, Saturn's large...  2023-03
# 84   How far out will humanity explore? If this vid...  2023-03
# 69   Put on your red/blue glasses and float next to...  2023-03
# 95   Relativity's Terran 1 Rocket is mostly 3D-prin...  2023-04
# 139  Looping through the Jovian system in the late ...  2023-05
# 147  This asteroid has a moon.  The robot spacecraf...  2023-05
# 125  Transformed into the petals of a flower, 16 ex...  2023-05
# 130  Fomalhaut is a bright star, a 25 light-year vo...  2023-05
# 174  The multicolor, stereo imaging Mastcam-Z on th...  2023-06
# 156  It’s the end of a world as we know it. Specifi...  2023-06
# 202  A photograph of Buzz Aldrin standing on the Mo...  2023-07
# 186  On July 4, an almost Full Moon rose in planet ...  2023-07
# 188  Stickney Crater, the largest crater on the mar...  2023-07
# 193  A mere 390 light-years away, Sun-like stars an...  2023-07
# 241  Near perigee, the closest point in its almost ...  2023-08
# 214  In a photo from the early hours of July 29 (UT...  2023-08
# 215  A Full Moon rose as the Sun set on August 1. N...  2023-08
#
#              Colaborador Colaborador2 Categoria Subcategoria
# 5           Niveth Kumar         None   Planeta         None
# 55          Fefo Bouvier         None   Planeta         None
# 31   \nMichael Carroll\n         None   Planeta         None
# 89                  None         None   Planeta         None
# 84                  None         None   Planeta         None
# 69                  None         None   Planeta         None
# 95                  None         None   Planeta         None
# 139                 None         None   Planeta         None
# 147                 None         None   Planeta         None
# 125     Dario Giannobile         None   Planeta         None
# 130                 None         None   Planeta         None
# 174                 None         None   Planeta         None
# 156                 None         None   Planeta         None
# 202                 None         None   Planeta         None
# 186       Michael Seeley         None   Planeta         None
# 188                 None         None   Planeta         None
# 193                 None         None   Planeta         None
# 241        Gianni Tumino         None   Planeta         None
# 214     Launch Complex 5         None   Planeta         None
# 215        Gianni Tumino         None   Planeta         None

# %% [markdown]
# ## Análisis y visualización:

# %%
# Agrupar los eventos por Periodo y Categoría y contar cuántos hay en cada categoría para cada mes
conteo_eventos = eventos_df.groupby(['periodo', 'Categoria']).size().reset_index(name='Conteo')

# Ordenar el DataFrame por la columna "periodo"
conteo_eventos = conteo_eventos.sort_values(by='periodo')

# Crear un gráfico de barras apiladas
fig = px.bar(conteo_eventos, x='periodo', y='Conteo', color='Categoria', title='Eventos Astronómicos por Periodo y Categoría desde el 2020 al 2023')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4b9246d9-95d3-446f-a9d7-af232db5e823" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b9246d9-95d3-446f-a9d7-af232db5e823")) {                    Plotly.newPlot(                        "4b9246d9-95d3-446f-a9d7-af232db5e823",                        [{"alignmentgroup":"True","hovertemplate":"Categoria=Asterismo\u003cbr\u003eperiodo=%{x}\u003cbr\u003eConteo=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Asterismo","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Asterismo","offsetgroup":"Asterismo","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-01"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoria=Aurora\u003cbr\u003eperiodo=%{x}\u003cbr\u003eConteo=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aurora","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Aurora","offsetgroup":"Aurora","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-01","2023-04","2023-07","2023-08"],"xaxis":"x","y":[2,2,2,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoria=Cometa\u003cbr\u003eperiodo=%{x}\u003cbr\u003eConteo=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cometa","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Cometa","offsetgroup":"Cometa","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-01","2023-02","2023-03","2023-04","2023-05","2023-07","2023-08","2023-09"],"xaxis":"x","y":[9,6,5,1,3,2,4,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoria=Galaxia\u003cbr\u003eperiodo=%{x}\u003cbr\u003eConteo=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Galaxia","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Galaxia","offsetgroup":"Galaxia","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-01","2023-02","2023-03","2023-04","2023-05","2023-06","2023-07","2023-08","2023-09"],"xaxis":"x","y":[8,7,7,7,8,7,9,3,3],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoria=Nebulosa\u003cbr\u003eperiodo=%{x}\u003cbr\u003eConteo=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Nebulosa","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Nebulosa","offsetgroup":"Nebulosa","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-01","2023-02","2023-03","2023-04","2023-05","2023-06","2023-07","2023-08","2023-09"],"xaxis":"x","y":[3,4,4,6,2,5,5,6,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoria=Planeta\u003cbr\u003eperiodo=%{x}\u003cbr\u003eConteo=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Planeta","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Planeta","offsetgroup":"Planeta","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-01","2023-02","2023-03","2023-04","2023-05","2023-06","2023-07","2023-08","2023-09"],"xaxis":"x","y":[3,4,9,3,9,10,6,9,1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoria=Sat\u00e9lite Natural\u003cbr\u003eperiodo=%{x}\u003cbr\u003eConteo=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sat\u00e9lite Natural","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sat\u00e9lite Natural","offsetgroup":"Sat\u00e9lite Natural","orientation":"v","showlegend":true,"textposition":"auto","x":["2023-01","2023-02","2023-04","2023-05","2023-06","2023-07","2023-09"],"xaxis":"x","y":[2,1,1,1,1,4,2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoria=Supernova\u003cbr\u003eperiodo=%{x}\u003cbr\u003eConteo=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sup ...

# %%
# Agrupar los eventos por Periodo y Categoría y contar cuántos hay en cada categoría para cada mes
conteo_eventos = eventos_df.groupby(['Colaborador']).size().reset_index(name='Conteo')
conteo_eventos['Colaborador'] = conteo_eventos['Colaborador'].str[:40]
# Crear un gráfico de barras apiladas
fig = px.bar(conteo_eventos, y='Colaborador', x='Conteo', color='Colaborador', title='Eventos Astronómicos redactado por:')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0bf86aa5-34ec-4ea4-8e80-a90f286b9421" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0bf86aa5-34ec-4ea4-8e80-a90f286b9421")) {                    Plotly.newPlot(                        "0bf86aa5-34ec-4ea4-8e80-a90f286b9421",                        [{"alignmentgroup":"True","hovertemplate":"Colaborador=%{y}\u003cbr\u003eConteo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\nAbdullah Al-Harbi\n","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"\nAbdullah Al-Harbi\n","offsetgroup":"\nAbdullah Al-Harbi\n","orientation":"h","showlegend":true,"textposition":"auto","x":[2],"xaxis":"x","y":["\nAbdullah Al-Harbi\n"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Colaborador=%{y}\u003cbr\u003eConteo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\nAbe Jones\n","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"\nAbe Jones\n","offsetgroup":"\nAbe Jones\n","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["\nAbe Jones\n"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Colaborador=%{y}\u003cbr\u003eConteo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\nAdam Block","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"\nAdam Block","offsetgroup":"\nAdam Block","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["\nAdam Block"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Colaborador=%{y}\u003cbr\u003eConteo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\nAleix Roig \n(AstroCatInfo)\n","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"\nAleix Roig \n(AstroCatInfo)\n","offsetgroup":"\nAleix Roig \n(AstroCatInfo)\n","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["\nAleix Roig \n(AstroCatInfo)\n"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Colaborador=%{y}\u003cbr\u003eConteo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\nAmr Abdulwahab\n","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"\nAmr Abdulwahab\n","offsetgroup":"\nAmr Abdulwahab\n","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["\nAmr Abdulwahab\n"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Colaborador=%{y}\u003cbr\u003eConteo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\nB. M\u00e9nard & \nN. Shtarkman;\nData:  \nSDSS","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"\nB. M\u00e9nard & \nN. Shtarkman;\nData:  \nSDSS","offsetgroup":"\nB. M\u00e9nard & \nN. Shtarkman;\nData:  \nSDSS","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["\nB. M\u00e9nard & \nN. Shtarkman;\nData:  \nSDSS"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Colaborador=%{y}\u003cbr\u003eConteo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\nBray Falls & \nChester Hall-Fernandez\n","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"\nBray Falls & \nChester Hall-Fernandez\n","offsetgroup":"\nBray Falls & \nChester Hall-Fernandez\n","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["\nBray Falls & \nChester Hall-Fernandez\n"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Colaborador=%{y}\u003cbr\u003eConteo=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\nBrian Brennan\n","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"\nBrian Brennan\n","offsetgroup":"\nBrian Brennan\n","orientation":"h","showlegend":true,"textposition":"auto","x":[1],"xaxis":"x","y":["\n ...

# %% [markdown]
# ## Almacenar:
# La última parte del proceso de organización es almacenar o preservar el producto final, junto con todos los pasos y transformaciones que se llevaron a cabo para que se pueda auditar, comprender y repetir en el futuro.

# %%
from google.colab import files

eventos_df.to_csv("resultados.csv")
files.download('resultados.csv')
